# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Modeling-and-Simulation-in-Python" data-toc-modified-id="Modeling-and-Simulation-in-Python-1">Modeling and Simulation in Python</a></span><ul class="toc-item"><li><span><a href="#Modeling-a-bikeshare-system" data-toc-modified-id="Modeling-a-bikeshare-system-1.1">Modeling a bikeshare system</a></span></li><li><span><a href="#Updating" data-toc-modified-id="Updating-1.2">Updating</a></span></li><li><span><a href="#Functions" data-toc-modified-id="Functions-1.3">Functions</a></span></li><li><span><a href="#Conditionals" data-toc-modified-id="Conditionals-1.4">Conditionals</a></span></li><li><span><a href="#Step" data-toc-modified-id="Step-1.5">Step</a></span></li><li><span><a href="#Parameters" data-toc-modified-id="Parameters-1.6">Parameters</a></span></li><li><span><a href="#For-loop" data-toc-modified-id="For-loop-1.7">For loop</a></span></li><li><span><a href="#TimeSeries" data-toc-modified-id="TimeSeries-1.8">TimeSeries</a></span></li><li><span><a href="#Plotting" data-toc-modified-id="Plotting-1.9">Plotting</a></span></li><li><span><a href="#Opening-the-hood" data-toc-modified-id="Opening-the-hood-1.10">Opening the hood</a></span><ul class="toc-item"><li><span><a href="#Pandas" data-toc-modified-id="Pandas-1.10.1">Pandas</a></span></li><li><span><a href="#Pyplot" data-toc-modified-id="Pyplot-1.10.2">Pyplot</a></span></li><li><span><a href="#NumPy" data-toc-modified-id="NumPy-1.10.3">NumPy</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Modeling and Simulation in Python
#
# Chapter 2
#
# Copyright 2017 Allen Downey
#
# License: [Creative Commons Attribution 4.0 International](https://creativecommons.org/licenses/by/4.0)

# %%
# Configure Jupyter so figures appear in the notebook
# %matplotlib inline

# Configure Jupyter to display the assigned value after an assignment
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'

# import functions from the modsim library
from modsim import *

# set the random number generator
np.random.seed(7)

# If this cell runs successfully, it produces no output.

# %% [markdown]
# ## Modeling a bikeshare system

# %% [markdown]
# We'll start with a `State` object that represents the number of bikes at each station.
#
# When you display a `State` object, it lists the state variables and their values:

# %%
bikeshare = State(olin=10, wellesley=2)
# Out:
# olin         10
# wellesley     2
# dtype: int64

# %% [markdown]
# We can access the state variables using dot notation.

# %%
bikeshare.olin
# Out:
# 10

# %%
bikeshare.wellesley
# Out:
# 2

# %% [markdown]
# **Exercise:** What happens if you spell the name of a state variable wrong?  Edit the previous cell, change the spelling of `wellesley`, and run the cell again.
#
# The error message uses the word "attribute", which is another name for what we are calling a state variable.

# %% [markdown]
# **Exercise:** Add a third attribute called `babson` with initial value 0, and display the state of `bikeshare` again.

# %%
bikeshare = State(olin=10, wellesley = 2, babson = 0)
# Out:
# olin         10
# wellesley     2
# babson        0
# dtype: int64

# %% [markdown]
# ## Updating
#
# We can use the update operators `+=` and `-=` to change state variables.

# %%
bikeshare.olin -= 1

# %% [markdown]
# If we display `bikeshare`, we should see the change.

# %%
bikeshare
# Out:
# olin         9
# wellesley    2
# babson       0
# dtype: int64

# %% [markdown]
# Of course, if we subtract a bike from `olin`, we should add it to `wellesley`.

# %%
bikeshare.wellesley += 1
bikeshare
# Out:
# olin         9
# wellesley    3
# babson       0
# dtype: int64

# %% [markdown]
# ## Functions
#
# We can take the code we've written so far and encapsulate it in a function.

# %%
def bike_to_wellesley():
    bikeshare.olin -= 1
    bikeshare.wellesley += 1

# %% [markdown]
# When you define a function, it doesn't run the statements inside the function, yet.  When you call the function, it runs the statements inside.

# %%
bike_to_wellesley()
bikeshare
# Out:
# olin         8
# wellesley    4
# babson       0
# dtype: int64

# %% [markdown]
# One common error is to omit the parentheses, which has the effect of looking up the function, but not calling it.

# %%
bike_to_wellesley
# Out:
# <function __main__.bike_to_wellesley()>

# %% [markdown]
# The output indicates that `bike_to_wellesley` is a function defined in a "namespace" called `__main__`, but you don't have to understand what that means.

# %% [markdown]
# **Exercise:** Define a function called `bike_to_olin` that moves a bike from Wellesley to Olin.  Call the new function and display `bikeshare`  to confirm that it works.

# %%
# Solution goes here
def bike_to_olin():
    bikeshare.wellesley -= 1
    bikeshare.olin += 1

# %%
# Solution goes here
bike_to_olin()
bikeshare
# Out:
# olin         9
# wellesley    3
# babson       0
# dtype: int64

# %% [markdown]
# ## Conditionals

# %% [markdown]
# `modsim.py` provides `flip`, which takes a probability and returns either `True` or `False`, which are special values defined by Python.
#
# The Python function `help` looks up a function and displays its documentation.

# %%
help(flip)
# Out:
# Help on function flip in module modsim.modsim:
#
# flip(p=0.5)
#     Flips a coin with the given probability.
#
#     p: float 0-1
#
#     returns: boolean (True or False)

# %% [markdown]
# In the following example, the probability is 0.7 or 70%.  If you run this cell several times, you should get `True` about 70% of the time and `False` about 30%.

# %%
for r in range(1,11):
    print(flip(0.7))
# Out:
# True
# False
# True
# False
# False
# True
# True
# True
# True
# True

# %%
#Discussion #1 Simulation: Flip a weighted coin 1000 times
fresults = []
intH = 0 
for r in range(1000):
    if flip(0.7) == True:
        fresults.append('H')
        intH += 1
    else:
        fresults.append('T')

print(f'Expected result is', 0.7 * 100, '%')
print(f'Actual result is', round(intH/1000 * 100,1), '%')
# Out:
# Expected result is 70.0 %
# Actual result is 72.6 %

# %% [markdown]
# In the following example, we use `flip` as part of an if statement.  If the result from `flip` is `True`, we print `heads`; otherwise we do nothing.

# %%
if flip(0.7):
    print('heads')
# Out:
# heads

# %% [markdown]
# With an else clause, we can print heads or tails depending on whether `flip` returns `True` or `False`.

# %%
if flip(0.7):
    print('heads')
else:
    print('tails')
# Out:
# tails

# %% [markdown]
# ## Step
#
# Now let's get back to the bikeshare state.  Again let's start with a new `State` object.

# %%
bikeshare = State(olin=10, wellesley=2)
# Out:
# olin         10
# wellesley     2
# dtype: int64

# %% [markdown]
# Suppose that in any given minute, there is a 50% chance that a student picks up a bike at Olin and rides to Wellesley.  We can simulate that like this.

# %%
if flip(0.5):
    bike_to_wellesley()
    print('Moving a bike to Wellesley')

bikeshare
# Out:
# Moving a bike to Wellesley
# olin         9
# wellesley    3
# dtype: int64

# %% [markdown]
# And maybe at the same time, there is also a 40% chance that a student at Wellesley rides to Olin.

# %%
if flip(0.4):
    bike_to_olin()
    print('Moving a bike to Olin')

bikeshare
# Out:
# Moving a bike to Olin
# olin         10
# wellesley     2
# dtype: int64

# %% [markdown]
# We can wrap that code in a function called `step` that simulates one time step.  In any given minute, a student might ride from Olin to Wellesley, from Wellesley to Olin, or both, or neither, depending on the results of `flip`.

# %%
def step():
    if flip(0.5):
        bike_to_wellesley()
        print('Moving a bike to Wellesley')
        
    if flip(0.4):
        bike_to_olin()
        print('Moving a bike to Olin')

# %% [markdown]
# Since this function takes no parameters, we call it like this:

# %%
step()
bikeshare
# Out:
# Moving a bike to Wellesley
# olin         9
# wellesley    3
# dtype: int64

# %% [markdown]
# ## Parameters
#
# As defined in the previous section, `step` is not as useful as it could be, because the probabilities `0.5` and `0.4` are "hard coded".
#
# It would be better to generalize this function so it takes the probabilities `p1` and `p2` as parameters:

# %%
def step(p1, p2):
    if flip(p1):
        bike_to_wellesley()
        print('Moving a bike to Wellesley')
        
    if flip(p2):
        bike_to_olin()
        print('Moving a bike to Olin')

# %% [markdown]
# Now we can call it like this:

# %%
step(0.5, 0.4)
bikeshare
# Out:
# Moving a bike to Wellesley
# olin         8
# wellesley    4
# dtype: int64

# %% [markdown]
# **Exercise:** At the beginning of `step`, add a print statement that displays the values of `p1` and `p2`.  Call it again with values `0.3`, and `0.2`, and confirm that the values of the parameters are what you expect.

# %%
# Solution goes here
def step(p1, p2):
    print(f'p1 is',p1,'and p2 is', p2)
    
    if flip(p1):
        bike_to_wellesley()
        print('Moving a bike to Wellesley')
        
    if flip(p2):
        bike_to_olin()
        print('Moving a bike to Olin')
        
step(0.3, 0.2)
# Out:
# p1 is 0.3 and p2 is 0.2
# Moving a bike to Olin

# %% [markdown]
# ## For loop

# %% [markdown]
# Before we go on, I'll redefine `step` without the print statements.

# %%
def step(p1, p2):
    if flip(p1):
        bike_to_wellesley()
    
    if flip(p2):
        bike_to_olin()

# %% [markdown]
# And let's start again with a new `State` object:

# %%
bikeshare = State(olin=10, wellesley=2)
# Out:
# olin         10
# wellesley     2
# dtype: int64

# %% [markdown]
# We can use a `for` loop to move 4 bikes from Olin to Wellesley.

# %%
for i in range(4):
    bike_to_wellesley()
    
bikeshare
# Out:
# olin         6
# wellesley    6
# dtype: int64

# %% [markdown]
# Or we can simulate 4 random time steps.

# %%
for i in range(4):
    step(0.3, 0.2)
    
bikeshare
# Out:
# olin         6
# wellesley    6
# dtype: int64

# %% [markdown]
# If each step corresponds to a minute, we can simulate an entire hour like this.

# %%
for i in range(60):
    step(0.3, 0.2)

bikeshare
# Out:
# olin         -2
# wellesley    14
# dtype: int64

# %% [markdown]
# After 60 minutes, you might see that the number of bike at Olin is negative.  We'll fix that problem in the next notebook.
#
# But first, we want to plot the results.

# %% [markdown]
# ## TimeSeries
#
# `modsim.py` provides an object called a `TimeSeries` that can contain a sequence of values changing over time.
#
# We can create a new, empty `TimeSeries` like this:

# %%
results = TimeSeries()
# Out:
# TimeSeries([], dtype: float64)

# %% [markdown]
# And we can add a value to the `TimeSeries` like this:

# %%
results[0] = bikeshare.olin
results
# Out:
# 0   -2
# dtype: int64

# %% [markdown]
# The `0` in brackets is an `index` that indicates that this value is associated with time step 0.
#
# Now we'll use a for loop to save the results of the simulation.  I'll start one more time with a new `State` object.

# %%
bikeshare = State(olin=10, wellesley=2)
# Out:
# olin         10
# wellesley     2
# dtype: int64

# %% [markdown]
# Here's a for loop that runs 10 steps and stores the results.

# %%
for i in range(10):
    step(0.3, 0.2)
    results[i] = bikeshare.olin

# %% [markdown]
# Now we can display the results.

# %%
results
# Out:
# 0    10
# 1     9
# 2     9
# 3     8
# 4     8
# 5     8
# 6     7
# 7     7
# 8     7
# 9     7
# dtype: int64

# %% [markdown]
# A `TimeSeries` is a specialized version of a Pandas `Series`, so we can use any of the functions provided by `Series`, including several that compute summary statistics:

# %%
results.mean()
# Out:
# 8.0

# %%
results.describe()
# Out:
# count    10.000000
# mean      8.000000
# std       1.054093
# min       7.000000
# 25%       7.000000
# 50%       8.000000
# 75%       8.750000
# max      10.000000
# dtype: float64

# %% [markdown]
# You can read the documentation of `Series` [here](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.html).

# %% [markdown]
# ## Plotting
#
# We can also plot the results like this.

# %%
plot(results, label='Olin')

decorate(title='Olin-Wellesley Bikeshare',
         xlabel='Time step (min)', 
         ylabel='Number of bikes')

savefig('figs/chap02-fig01.pdf')
# Out:
# Saving figure to file figs/chap02-fig01.pdf

# %% [markdown]
# `decorate`, which is defined in the `modsim` library, adds a title and labels the axes.

# %%
help(decorate)
# Out:
# Help on function decorate in module modsim.modsim:
#
# decorate(**options)
#     Decorate the current axes.
#
#     Call decorate with keyword arguments like
#
#     decorate(title='Title',
#              xlabel='x',
#              ylabel='y')
#
#     The keyword arguments can be any of the axis properties
#
#     https://matplotlib.org/api/axes_api.html
#
#     In addition, you can use `legend=False` to suppress the legend.
#
#     And you can use `loc` to indicate the location of the legend
#     (the default value is 'best')

# %% [markdown]
# `savefig()` saves a figure in a file.

# %%
help(savefig)
# Out:
# Help on function savefig in module modsim.modsim:
#
# savefig(filename, **options)
#     Save the current figure.
#
#     Keyword arguments are passed along to plt.savefig
#
#     https://matplotlib.org/api/_as_gen/matplotlib.pyplot.savefig.html
#
#     filename: string

# %% [markdown]
# The suffix of the filename indicates the format you want.  This example saves the current figure in a PDF file.

# %% [markdown]
# **Exercise:** Wrap the code from this section in a function named `run_simulation` that takes three parameters, named `p1`, `p2`, and `num_steps`.
#
# It should:
#
# 1. Create a `TimeSeries` object to hold the results.
# 2. Use a for loop to run `step` the number of times specified by `num_steps`, passing along the specified values of `p1` and `p2`.
# 3. After each step, it should save the number of bikes at Olin in the `TimeSeries`.
# 4. After the for loop, it should plot the results and
# 5. Decorate the axes.
#
# To test your function:
#
# 1. Create a `State` object with the initial state of the system.
# 2. Call `run_simulation` with appropriate parameters.
# 3. Save the resulting figure.
#
# Optional:
#
# 1. Extend your solution so it creates two `TimeSeries` objects, keeps track of the number of bikes at Olin *and* at Wellesley, and plots both series at the end.

# %%
# Solution goes here
def run_simulation(p1, p2, num_steps):
    sim_results = TimeSeries()
    
    for r in range(num_steps):
        step(p1, p2)
        sim_results[r] = bikeshare.olin
    
    plot(sim_results, label='Olin')

    decorate(title='Olin-Wellesley Bikeshare',
             xlabel='Time step (min)', 
             ylabel='Number of bikes')

# %%
# Solution goes here
bikeshare = State(olin=6, wellesley=6)
run_simulation(0.4, 0.6, 10)
savefig('figs/chap02-fig02.pdf')
# Out:
# Saving figure to file figs/chap02-fig02.pdf

# %% [markdown]
# ## Opening the hood
#
# The functions in `modsim.py` are built on top of several widely-used Python libraries, especially NumPy, SciPy, and Pandas.  These libraries are powerful but can be hard to use.  The intent of `modsim.py` is to give you the power of these libraries while making it easy to get started.
#
# In the future, you might want to use these libraries directly, rather than using `modsim.py`.  So we will pause occasionally to open the hood and let you see how `modsim.py` works.
#
# You don't need to know anything in these sections, so if you are already feeling overwhelmed, you might want to skip them.  But if you are curious, read on.

# %% [markdown]
# ### Pandas
#
# This chapter introduces two objects, `State` and `TimeSeries`.  Both are based on the `Series` object defined by Pandas, which is a library primarily used for data science.
#
# You can read the documentation of the `Series` object [here](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.html)
#
# The primary differences between `TimeSeries` and `Series` are:
#
# 1. I made it easier to create a new, empty `Series` while avoiding a [confusing inconsistency](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.html).
#
# 2. I provide a function so the `Series` looks good when displayed in Jupyter.
#
# 3. I provide a function called `set` that we'll use later.
#
# `State` has all of those capabilities; in addition, it provides an easier way to initialize state variables, and it provides functions called `T` and `dt`, which will help us avoid a confusing error later.

# %% [markdown]
# ### Pyplot
#
# The `plot` function in `modsim.py` is based on the `plot` function in Pyplot, which is part of Matplotlib.  You can read the documentation of `plot` [here](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html).
#
# `decorate` provides a convenient way to call the `pyplot` functions `title`, `xlabel`, and `ylabel`, and `legend`.  It also avoids an annoying warning message if you try to make a legend when you don't have any labelled lines.

# %%
help(decorate)
# Out:
# Help on function decorate in module modsim.modsim:
#
# decorate(**options)
#     Decorate the current axes.
#
#     Call decorate with keyword arguments like
#
#     decorate(title='Title',
#              xlabel='x',
#              ylabel='y')
#
#     The keyword arguments can be any of the axis properties
#
#     https://matplotlib.org/api/axes_api.html
#
#     In addition, you can use `legend=False` to suppress the legend.
#
#     And you can use `loc` to indicate the location of the legend
#     (the default value is 'best')

# %% [markdown]
# ### NumPy
#
# The `flip` function in `modsim.py` uses NumPy's `random` function to generate a random number between 0 and 1.
#
# You can get the source code for `flip` by running the following cell.

# %%
source_code(flip)
# Out:
# def flip(p=0.5):
#     """Flips a coin with the given probability.
#
#     p: float 0-1
#
#     returns: boolean (True or False)
#     """
#     return np.random.random() < p
