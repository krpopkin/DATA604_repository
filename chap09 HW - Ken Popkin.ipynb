# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Modeling-and-Simulation-in-Python" data-toc-modified-id="Modeling-and-Simulation-in-Python-1">Modeling and Simulation in Python</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Analysis-with-SymPy" data-toc-modified-id="Analysis-with-SymPy-1.0.1">Analysis with SymPy</a></span></li><li><span><a href="#Solving-the-quadratic-growth-equation" data-toc-modified-id="Solving-the-quadratic-growth-equation-1.0.2">Solving the quadratic growth equation</a></span></li><li><span><a href="#Exercises" data-toc-modified-id="Exercises-1.0.3">Exercises</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Modeling and Simulation in Python
#
# Chapter 9
#
# Copyright 2017 Allen Downey
#
# License: [Creative Commons Attribution 4.0 International](https://creativecommons.org/licenses/by/4.0)

# %%
# Configure Jupyter to display the assigned value after an assignment
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'

# import everything from SymPy.
from sympy import *

# Set up Jupyter notebook to display math.
init_printing()

# %% [markdown]
# The following displays SymPy expressions and provides the option of showing results in LaTeX format.

# %%
from sympy.printing import latex

def show(expr, show_latex=False):
    """Display a SymPy expression.
    
    expr: SymPy expression
    show_latex: boolean
    """
    if show_latex:
        print(latex(expr))
    return expr

# %% [markdown]
# ### Analysis with SymPy

# %% [markdown]
# Create a symbol for time.

# %%
t = symbols('t')
# Out:
# t

# %% [markdown]
# If you combine symbols and numbers, you get symbolic expressions.

# %%
expr = t + 1
# Out:
# t + 1

# %% [markdown]
# The result is an `Add` object, which just represents the sum without trying to compute it.

# %%
type(expr)
# Out:
# sympy.core.add.Add

# %% [markdown]
# `subs` can be used to replace a symbol with a number, which allows the addition to proceed.

# %%
expr.subs(t, 2)
# Out:
# 3

# %% [markdown]
# `f` is a special class of symbol that represents a function.

# %%
f = Function('f')
# Out:
# f

# %% [markdown]
# The type of `f` is `UndefinedFunction`

# %%
type(f)
# Out:
# sympy.core.function.UndefinedFunction

# %% [markdown]
# SymPy understands that `f(t)` means `f` evaluated at `t`, but it doesn't try to evaluate it yet.

# %%
f(t)
# Out:
# f(t)

# %% [markdown]
# `diff` returns a `Derivative` object that represents the time derivative of `f`

# %%
dfdt = diff(f(t), t)
# Out:
# d
# ──(f(t))
# dt

# %%
type(dfdt)
# Out:
# sympy.core.function.Derivative

# %% [markdown]
# We need a symbol for `alpha`

# %%
alpha = symbols('alpha')
# Out:
# α

# %% [markdown]
# Now we can write the differential equation for proportional growth.

# %%
eq1 = Eq(dfdt, alpha*f(t))
# Out:
# d
# ──(f(t)) = α⋅f(t)
# dt

# %% [markdown]
# And use `dsolve` to solve it.  The result is the general solution.

# %%
solution_eq = dsolve(eq1)
# Out:
#            α⋅t
# f(t) = C₁⋅ℯ

# %% [markdown]
# We can tell it's a general solution because it contains an unspecified constant, `C1`.
#
# In this example, finding the particular solution is easy: we just replace `C1` with `p_0`

# %%
C1, p_0 = symbols('C1 p_0')

# %%
particular = solution_eq.subs(C1, p_0)
# Out:
#            α⋅t
# f(t) = p₀⋅ℯ

# %% [markdown]
# In the next example, we have to work a little harder to find the particular solution.

# %% [markdown]
# ### Solving the quadratic growth equation
#
# We'll use the (r, K) parameterization, so we'll need two more symbols:

# %%
r, K = symbols('r K')

# %% [markdown]
# Now we can write the differential equation.

# %%
eq2 = Eq(diff(f(t), t), r * f(t) * (1 - f(t)/K))
# Out:
# d            ⎛    f(t)⎞
# ──(f(t)) = r⋅⎜1 - ────⎟⋅f(t)
# dt           ⎝     K  ⎠

# %% [markdown]
# And solve it.

# %%
solution_eq = dsolve(eq2)
# Out:
#            C₁⋅K + r⋅t
#         K⋅ℯ
# f(t) = ───────────────
#         C₁⋅K + r⋅t
#        ℯ           - 1

# %% [markdown]
# The result, `solution_eq`, contains `rhs`, which is the right-hand side of the solution.

# %%
general = solution_eq.rhs
# Out:
#     C₁⋅K + r⋅t
#  K⋅ℯ
# ───────────────
#  C₁⋅K + r⋅t
# ℯ           - 1

# %% [markdown]
# We can evaluate the right-hand side at $t=0$

# %%
at_0 = general.subs(t, 0)
# Out:
#     C₁⋅K
#  K⋅ℯ
# ─────────
#  C₁⋅K
# ℯ     - 1

# %% [markdown]
# Now we want to find the value of `C1` that makes `f(0) = p_0`.
#
# So we'll create the equation `at_0 = p_0` and solve for `C1`.  Because this is just an algebraic identity, not a differential equation, we use `solve`, not `dsolve`.
#
# The result from `solve` is a list of solutions.  In this case, [we have reason to expect only one solution](https://en.wikipedia.org/wiki/Picard%E2%80%93Lindel%C3%B6f_theorem), but we still get a list, so we have to use the bracket operator, `[0]`, to select the first one.

# %%
solutions = solve(Eq(at_0, p_0), C1)
type(solutions), len(solutions)
# Out:
# (list, 1)

# %%
value_of_C1 = solutions[0]
# Out:
#    ⎛ -p₀  ⎞
# log⎜──────⎟
#    ⎝K - p₀⎠
# ───────────
#      K

# %% [markdown]
# Now in the general solution, we want to replace `C1` with the value of `C1` we just figured out.

# %%
particular = general.subs(C1, value_of_C1)
# Out:
#              r⋅t
#       -K⋅p₀⋅ℯ
# ────────────────────────
#          ⎛      r⋅t    ⎞
#          ⎜  p₀⋅ℯ       ⎟
# (K - p₀)⋅⎜- ─────── - 1⎟
#          ⎝   K - p₀    ⎠

# %% [markdown]
# The result is complicated, but SymPy provides a method that tries to simplify it.

# %%
particular = simplify(particular)
# Out:
#          r⋅t
#    K⋅p₀⋅ℯ
# ────────────────
#         r⋅t
# K + p₀⋅ℯ    - p₀

# %% [markdown]
# Often simplicity is in the eye of the beholder, but that's about as simple as this expression gets.
#
# Just to double-check, we can evaluate it at `t=0` and confirm that we get `p_0`

# %%
particular.subs(t, 0)
# Out:
# p₀

# %% [markdown]
# This solution is called the [logistic function](https://en.wikipedia.org/wiki/Population_growth#Logistic_equation).
#
# In some places you'll see it written in a different form:
#
# $f(t) = \frac{K}{1 + A e^{-rt}}$
#
# where $A = (K - p_0) / p_0$.
#
# We can use SymPy to confirm that these two forms are equivalent.  First we represent the alternative version of the logistic function:

# %%
A = (K - p_0) / p_0
# Out:
# K - p₀
# ──────
#   p₀

# %%
logistic = K / (1 + A * exp(-r*t))
# Out:
#         K
# ──────────────────
#               -r⋅t
#     (K - p₀)⋅ℯ
# 1 + ──────────────
#           p₀

# %% [markdown]
# To see whether two expressions are equivalent, we can check whether their difference simplifies to 0.

# %%
simplify(particular - logistic)
# Out:
# 0

# %% [markdown]
# This test only works one way: if SymPy says the difference reduces to 0, the expressions are definitely equivalent (and not just numerically close).
#
# But if SymPy can't find a way to simplify the result to 0, that doesn't necessarily mean there isn't one.  Testing whether two expressions are equivalent is a surprisingly hard problem; in fact, there is no algorithm that can solve it in general.

# %% [markdown]
# ### Exercises
#
# **Exercise:** Solve the quadratic growth equation using the alternative parameterization
#
# $\frac{df(t)}{dt} = \alpha f(t) + \beta f^2(t) $

# %%
# Solution goes here
beta = symbols('beta')
eq3 = Eq(diff(f(t), t), alpha * f(t) + beta * (f(t)**2))
# Out:
# d                      2
# ──(f(t)) = α⋅f(t) + β⋅f (t)
# dt

# %%
# Solution goes here
solution_eq2 = dsolve(eq3)
# Out:
#              α⋅(C₁ + t)
#           α⋅ℯ
# f(t) = ───────────────────
#          ⎛     α⋅(C₁ + t)⎞
#        β⋅⎝1 - ℯ          ⎠

# %%
# Solution goes here
general2 = solution_eq2.rhs
# Out:
#       α⋅(C₁ + t)
#    α⋅ℯ
# ───────────────────
#   ⎛     α⋅(C₁ + t)⎞
# β⋅⎝1 - ℯ          ⎠

# %%
# Solution goes here
at_02 = general2.subs(t, 0)
# Out:
#       C₁⋅α
#    α⋅ℯ
# ─────────────
#   ⎛     C₁⋅α⎞
# β⋅⎝1 - ℯ    ⎠

# %%
# Solution goes here
solutions2 = solve(Eq(at_02, p_0), C1)
# Out:
# ⎡   ⎛  β⋅p₀  ⎞⎤
# ⎢log⎜────────⎟⎥
# ⎢   ⎝α + β⋅p₀⎠⎥
# ⎢─────────────⎥
# ⎣      α      ⎦

# %%
# Solution goes here
value_of_C1 = solutions2[0]
# Out:
#    ⎛  β⋅p₀  ⎞
# log⎜────────⎟
#    ⎝α + β⋅p₀⎠
# ─────────────
#       α

# %%
# Solution goes here
particular2 = general2.subs(C1, value_of_C1)
# Out:
#         ⎛       ⎛  β⋅p₀  ⎞⎞
#         ⎜    log⎜────────⎟⎟
#         ⎜       ⎝α + β⋅p₀⎠⎟
#       α⋅⎜t + ─────────────⎟
#         ⎝          α      ⎠
#    α⋅ℯ
# ──────────────────────────────
#   ⎛       ⎛       ⎛  β⋅p₀  ⎞⎞⎞
#   ⎜       ⎜    log⎜────────⎟⎟⎟
#   ⎜       ⎜       ⎝α + β⋅p₀⎠⎟⎟
#   ⎜     α⋅⎜t + ─────────────⎟⎟
#   ⎜       ⎝          α      ⎠⎟
# β⋅⎝1 - ℯ                     ⎠

# %%
particular2 = simplify(particular2)
# Out:
#            α⋅t
#      α⋅p₀⋅ℯ
# ────────────────────
#           α⋅t
# α - β⋅p₀⋅ℯ    + β⋅p₀

# %%
particular2.subs(t, 0)
# Out:
# p₀

# %% [markdown]
# **Exercise:**  Use [WolframAlpha](https://www.wolframalpha.com/) to solve the quadratic growth model, using either or both forms of parameterization:
#
#     df(t) / dt = alpha f(t) + beta f(t)^2
#
# or
#
#     df(t) / dt = r f(t) (1 - f(t)/K)
#
# Find the general solution and also the particular solution where `f(0) = p_0`.
